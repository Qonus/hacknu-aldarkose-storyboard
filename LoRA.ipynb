# %%
# !git clone https://github.com/ostris/ai-toolkit.git

# %cd ai-toolkit

# !git submodule update --init --recursive
# Out:
# fatal: destination path 'ai-toolkit' already exists and is not an empty directory.
# /workspace/ai-toolkit

# %%
# !python3 -m venv venv

# !source venv/bin/activate

# %%
# !pip install torch
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting git+https://github.com/jaretburkett/easy_dwpose.git (from -r requirements.txt (line 3))
#   Cloning https://github.com/jaretburkett/easy_dwpose.git to /tmp/pip-req-build-9fvgi_o4
#   Running command git clone --filter=blob:none --quiet https://github.com/jaretburkett/easy_dwpose.git /tmp/pip-req-build-9fvgi_o4
#   Resolved https://github.com/jaretburkett/easy_dwpose.git to commit 028aa1449f9e07bdeef7f84ed0ce7a2660e72239
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/huggingface/diffusers@1448b035859dd57bbb565239dcdd79a025a85422 (from -r requirements.txt (line 4))
#   Cloning https://github.com/huggingface/diffusers (to revision 1448b035859dd57bbb565239dcdd79a025a85422) to /tmp/pip-req-build-3pcnq6sq
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-3pcnq6sq
#   Running command git rev-parse -q --verify 'sha^1448b035859dd57bbb565239dcdd79a025a85422'
#   Running command git fetch -q https://github.com/huggingface/diffusers 1448b035859dd57bbb565239dcdd79a025a85422
#   Running command git checkout -q 1448b035859dd57bbb565239dcdd79a025a85422
#   Resolved https://github.com/huggingface/diffusers to commit 1448b035859dd57bbb565239dcdd79a025a85422
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torchao==0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: transformers==4.52.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.52.4)
# Requirement already satisfied: lycoris-lora==1.8.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.8.3)
# Requirement already satisfied: flatten_json in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.1.14)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.8.1)
# Requirement already satisfied: invisible-watermark in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.8.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (1.10.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (0.10.2)
# Requirement already satisfied: albumentations==1.4.15 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (1.4.15)
# Requirement already satisfied: albucore==0.0.16 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (0.0.16)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (2.11.10)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (2.3.0)
# Requirement already satisfied: k-diffusion in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (0.1.1.post1)
# Requirement already satisfied: open_clip_torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (3.2.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (1.0.20)
# Requirement already satisfied: prodigyopt in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (1.1.2)
# Requirement already satisfied: controlnet_aux==0.0.10 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (0.0.10)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.48.1)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (0.1.9)
# Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (0.1.4)
# Requirement already satisfied: pytorch_fid in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (0.3.0)
# Requirement already satisfied: optimum-quanto==0.2.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 30)) (0.2.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 31)) (0.2.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 32)) (0.35.3)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (0.17.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 34)) (5.49.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 35)) (8.0.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (4.11.0.86)
# Requirement already satisfied: pytorch-wavelets==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 37)) (1.3.0)
# Requirement already satisfied: matplotlib==3.10.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 38)) (3.10.1)
# Requirement already satisfied: setuptools==69.5.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 39)) (69.5.1)
# Requirement already satisfied: imageio<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from easy_dwpose==1.0.3->-r requirements.txt (line 3)) (2.37.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from easy_dwpose==1.0.3->-r requirements.txt (line 3)) (0.7.3)
# Requirement already satisfied: numpy<2.0.0,>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from easy_dwpose==1.0.3->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: onnxruntime-gpu==1.21.1 in /usr/local/lib/python3.12/dist-packages (from easy_dwpose==1.0.3->-r requirements.txt (line 3)) (1.21.1)
# Requirement already satisfied: torch<3.0.0,>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from easy_dwpose==1.0.3->-r requirements.txt (line 3)) (2.5.1+cu121)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.5 in /usr/local/lib/python3.12/dist-packages (from easy_dwpose==1.0.3->-r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (2025.9.18)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (11.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 38)) (2.9.0.post0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers==4.52.4->-r requirements.txt (line 5)) (0.21.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.15->-r requirements.txt (line 16)) (1.16.2)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.15->-r requirements.txt (line 16)) (0.25.2)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.15->-r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.15->-r requirements.txt (line 16)) (4.11.0.86)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->-r requirements.txt (line 19)) (4.9.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from controlnet_aux==0.0.10->-r requirements.txt (line 24)) (0.20.1+cu121)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from optimum-quanto==0.2.4->-r requirements.txt (line 30)) (1.13.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from pytorch-wavelets==1.3.0->-r requirements.txt (line 37)) (1.17.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.21.1->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.21.1->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.21.1->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (6.33.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.21.1->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 32)) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 32)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 32)) (1.1.10)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.2.2->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu==1.21.1->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 10)) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 10)) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia->-r requirements.txt (line 11)) (0.1.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from invisible-watermark->-r requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 14)) (7.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r requirements.txt (line 18)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r requirements.txt (line 18)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r requirements.txt (line 18)) (0.4.2)
# Requirement already satisfied: clean-fid in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (0.1.35)
# Requirement already satisfied: clip-anytorch in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (2.6.0)
# Requirement already satisfied: dctorch in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (0.1.2)
# Requirement already satisfied: jsonmerge in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (1.9.2)
# Requirement already satisfied: torchdiffeq in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (0.2.5)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (0.2.6)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from k-diffusion->-r requirements.txt (line 20)) (0.22.2)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from open_clip_torch->-r requirements.txt (line 21)) (6.3.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.119.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.6.3)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (3.11.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (2.3.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.14.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.19.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 34)) (0.38.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio->-r requirements.txt (line 34)) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 34)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 34)) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 34)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 34)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 34)) (0.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 34)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio->-r requirements.txt (line 34)) (2025.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (14.2.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->-r requirements.txt (line 35)) (1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 34)) (0.1.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.15->-r requirements.txt (line 16)) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.15->-r requirements.txt (line 16)) (0.4)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime-gpu==1.21.1->easy_dwpose==1.0.3->-r requirements.txt (line 3)) (10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open_clip_torch->-r requirements.txt (line 21)) (0.2.14)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (3.23.0)
# Requirement already satisfied: jsonschema>2.4.0 in /usr/local/lib/python3.12/dist-packages (from jsonmerge->k-diffusion->-r requirements.txt (line 20)) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->-r requirements.txt (line 20)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->-r requirements.txt (line 20)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->-r requirements.txt (line 20)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>2.4.0->jsonmerge->k-diffusion->-r requirements.txt (line 20)) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.36.0.dev0->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from torchsde->k-diffusion->-r requirements.txt (line 20)) (0.1.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->k-diffusion->-r requirements.txt (line 20)) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->k-diffusion->-r requirements.txt (line 20)) (4.5.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->k-diffusion->-r requirements.txt (line 20)) (2.42.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->k-diffusion->-r requirements.txt (line 20)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->k-diffusion->-r requirements.txt (line 20)) (5.0.2)

# %%
# !python run.py config/examples/train_lora_flux_24gb.yaml
# Out:
# Running 1 job
# {
#     "type": "sd_trainer",
#     "training_folder": "output",
#     "device": "cuda:0",
#     "network": {
#         "type": "lora",
#         "linear": 16,
#         "linear_alpha": 16
#     },
#     "save": {
#         "dtype": "float16",
#         "save_every": 250,
#         "max_step_saves_to_keep": 4,
#         "push_to_hub": false
#     },
#     "datasets": [
#         {
#             "folder_path": "config/examples/Dataset",
#             "caption_ext": "txt",
#             "caption_dropout_rate": 0.05,
#             "shuffle_tokens": false,
#             "cache_latents_to_disk": true,
#             "resolution": [
#                 512,
#                 768,
#                 1024
#             ]
#         }
#     ],
#     "train": {
#         "batch_size": 1,
#         "steps": 2000,
#         "gradient_accumulation_steps": 1,
#         "train_unet": true,
#         "train_text_encoder": false,
#         "gradient_checkpointing": true,
#         "noise_scheduler": "flowmatch",
#         "optimizer": "adamw8bit",
#         "lr": 0.0001,
#         "ema_config": {
#             "use_ema": true,
#             "ema_decay": 0.99
#         },
#         "dtype": "bf16"
#     },
#     "model": {
#         "name_or_path": "black-forest-labs/FLUX.1-dev",
#         "is_flux": true,
#         "quantize": true
#     },
#     "sample": {
#         "sampler": "flowmatch",
#         "sample_every": 250,
#         "width": 1024,
#         "height": 1024,
#         "prompts": [
#             "Aldar wearing a taqya",
#             "Bay and his wife are eating"
#         ],
#         "neg": "",
#         "seed": 42,
#         "walk_seed": true,
#         "guidance_scale": 4,
#         "sample_steps": 20
#     }
# }
# Using EMA
#
# #############################################
# # Running job: my_first_flux_lora_v1
# #############################################
#
#
# Running  1 process
# Loading Flux model
# Loading transformer
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:00<00:00, 50.88it/s]
# Quantizing transformer
# Loading VAE
# Loading T5
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading checkpoint shards: 100%|██████████████████| 2/2 [00:00<00:00, 84.81it/s]
# Quantizing T5
# Loading CLIP
# Making pipe
# Preparing Model
# create LoRA network. base dim (rank): 16, alpha: 16
# neuron dropout: p=None, rank dropout: p=None, module dropout: p=None
# create LoRA for Text Encoder: 0 modules.
# create LoRA for U-Net: 494 modules.
# enable LoRA for U-Net
# #### IMPORTANT RESUMING FROM output/my_first_flux_lora_v1/my_first_flux_lora_v1.safetensors ####
# Loading from output/my_first_flux_lora_v1/my_first_flux_lora_v1.safetensors
# Missing keys: []
# Found step 2000 in metadata, starting from there
# Loading optimizer state from output/my_first_flux_lora_v1/optimizer.pt
# Updating optimizer LR from params
# Dataset: config/examples/Dataset
#   -  Preprocessing image dimensions
# 100%|██████████████████████████████████████████| 38/38 [00:00<00:00, 181.95it/s]
#   -  Found 38 images
# Bucket sizes for config/examples/Dataset:
# 672x384: 10 files
# 576x448: 9 files
# 512x512: 2 files
# 256x288: 1 files
# 576x416: 3 files
# 192x416: 1 files
# 416x416: 2 files
# 480x544: 3 files
# 448x320: 2 files
# 352x384: 1 files
# 224x480: 1 files
# 352x480: 1 files
# 384x576: 1 files
# 544x448: 1 files
# 14 buckets made
# Caching latents for config/examples/Dataset
#  - Saving latents to disk
# Caching latents to disk: 100%|██████████████████| 38/38 [00:00<00:00, 52.24it/s]
# Dataset: config/examples/Dataset
#   -  Preprocessing image dimensions
# 100%|████████████████████████████████████████| 38/38 [00:00<00:00, 56559.10it/s]
#   -  Found 38 images
# Bucket sizes for config/examples/Dataset:
# 992x576: 10 files
# 864x672: 11 files
# 736x736: 1 files
# 256x288: 1 files
# 608x448: 1 files
# 192x416: 1 files
# 416x416: 2 files
# 544x640: 2 files
# 448x320: 2 files
# 352x384: 1 files
# 224x480: 1 files
# 352x480: 1 files
# 608x672: 1 files
# 768x768: 1 files
# 384x576: 1 files
# 736x608: 1 files
# 16 buckets made
# Caching latents for config/examples/Dataset
#  - Saving latents to disk
# Caching latents to disk: 100%|██████████████████| 38/38 [00:00<00:00, 58.85it/s]
# Dataset: config/examples/Dataset
#   -  Preprocessing image dimensions
# 100%|████████████████████████████████████████| 38/38 [00:00<00:00, 57936.59it/s]
#   -  Found 38 images
# Bucket sizes for config/examples/Dataset:
# 1344x768: 7 files
# 1152x896: 9 files
# 736x736: 1 files
# 256x288: 1 files
# 608x448: 1 files
# 192x416: 1 files
# 416x416: 2 files
# 1248x704: 2 files
# 544x640: 2 files
# 448x320: 2 files
# 992x576: 1 files
# 352x384: 1 files
# 224x480: 1 files
# 352x480: 1 files
# 608x672: 1 files
# 1152x832: 2 files
# 768x768: 1 files
# 384x576: 1 files
# 736x608: 1 files
# 19 buckets made
# Caching latents for config/examples/Dataset
#  - Saving latents to disk
# Caching latents to disk: 100%|██████████████████| 38/38 [00:01<00:00, 36.03it/s]
# my_first_flux_lora_v1: 100%|████████████████████████| 2000/2000 [00:01<?, ?it/s]
#
# Saved checkpoint to output/my_first_flux_lora_v1/my_first_flux_lora_v1.safetensors
# Saved optimizer to output/my_first_flux_lora_v1/optimizer.pt
